# %%
from HebHTR import *

# Create new HebHTR object.
img = HebHTR('example.png')

# Infer words from image.
text = img.imgToWord(iterations=5, decoder_type='word_beam')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 7
#       4 img = HebHTR('example.png')
#       6 # Infer words from image.
# ----> 7 text = img.imgToWord(iterations=5, decoder_type='word_beam')
#
# File c:\Users\Lenovo\Desktop\work\g_cloud_vision\github_sample\HebHTR\HebHTR.py:14, in HebHTR.imgToWord(self, iterations, decoder_type)
#      12 def imgToWord(self, iterations=5, decoder_type='word_beam'):
#      13     transcribed_words = []
# ---> 14     model = getModel(decoder_type=decoder_type)
#      15     transcribed_words.extend(predictWord(self.original_img, model))
#      16     return transcribed_words
#
# File c:\Users\Lenovo\Desktop\work\g_cloud_vision\github_sample\HebHTR\predictWord.py:26, in getModel(decoder_type)
#      23 else:
#      24     decoderType = DecoderType.BestPath
# ---> 26 model = Model(open(FilePaths.fnCharList).read(), decoderType,
#      27               mustRestore=True)
#      28 return model
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 42: character maps to <undefined>
